# %%
import re
import csv

# Dictionary to convert month names to numbers
MONTHS = {
    "january": "01", "february": "02", "march": "03", "april": "04",
    "may": "05", "june": "06", "july": "07", "august": "08",
    "september": "09", "october": "10", "november": "11", "december": "12",
    "jan": "01", "feb": "02", "mar": "03", "apr": "04",
    "jun": "06", "jul": "07", "aug": "08",
    "sep": "09", "oct": "10", "nov": "11", "dec": "12"
}

# Define regex patterns for matching dates
DATE_PATTERNS = [
    r"(\d{1,2})(st|nd|rd|th)?[ ]?(January|February|March|April|May|June|July|August|September|October|November|December|Jan|Feb|Mar|Apr|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[, ]+(\d{4})",  # 21st June, 2024
    r"(\d{1,2})[ ]?(January|February|March|April|May|June|July|August|September|October|November|December|Jan|Feb|Mar|Apr|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[, ]+(\d{4})",  # 21 June 2024
    r"(\d{1,2})/(\d{1,2})/(\d{4})",  # 21/06/2024
    r"(\d{1,2})-(\d{1,2})-(\d{4})",  # 21-06-2024
    r"(January|February|March|April|May|June|July|August|September|October|November|December|Jan|Feb|Mar|Apr|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[ ]?(\d{1,2})(st|nd|rd|th)?,[ ]?(\d{4})",  # June 21, 2024
    r"(January|February|March|April|May|June|July|August|September|October|November|December|Jan|Feb|Mar|Apr|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[ ]?(\d{1,2})[, ]?(\d{4})",  # June 21 2024
    r"(\d{4})/(\d{1,2})/(\d{1,2})",  # 2024/06/21
    r"(\d{4})-(\d{1,2})-(\d{1,2})",  # 2024-06-21
    r"(\d{4})[.](\d{1,2})[.](\d{1,2})",  # 2024.06.21
    r"(\d{1,2})[.](\d{1,2})[.](\d{4})"  # 21.06.2024
]

def parse_date(text):
    for pattern in DATE_PATTERNS:
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            groups = match.groups()
            day, month, year = None, None, None

            if len(groups) == 4:  # For formats like 21st June, 2024 or June 21, 2024
                if groups[0].isdigit():  # 21st June, 2024
                    day, month, year = groups[0], groups[2], groups[3]
                else:  # June 21, 2024
                    day, month, year = groups[1], groups[0], groups[3]
            elif len(groups) == 3:  # For formats like 21 June 2024 or 21/06/2024
                if groups[0].isdigit() and groups[1].isdigit():  # 21/06/2024
                    day, month, year = groups[0], groups[1], groups[2]
                elif groups[1].isalpha():  # 21 June 2024
                    day, month, year = groups[0], groups[1], groups[2]
                else:  # 2024/06/21 or 2024-06-21
                    year, month, day = groups[0], groups[1], groups[2]
            elif len(groups) == 5:  # For formats like June 21st, 2024
                month, day, year = groups[0], groups[1], groups[3]
            elif len(groups) == 6:  # For formats like June 21st, 2024 with more groups
                month, day, year = groups[0], groups[1], groups[3]

            if month:
                month = MONTHS.get(month.lower(), month)
            
            if day and month and year:
                return f"{day.zfill(2)}/{month.zfill(2)}/{year}"
    return "Date not found"

# Read and process the dataset
def process_dataset(file_path):
    with open(file_path, mode='r') as file:
        csv_reader = csv.reader(file)
        next(csv_reader)  # Skip header if there is one
        for row in csv_reader:
            text = row[0]
            parsed_date = parse_date(text)
            print(f"Original text: {text}")
            print(f"Parsed date: {parsed_date}\n")

# Example usage
process_dataset('date_parser_testcases.csv')
# Out:
# Original text: The event will take place on March 5, 2023.
# Parsed date: 05/03/2023
#
# Original text: Her birthday is on 07/08/1990.
# Parsed date: 07/08/1990
#
# Original text: The deadline is 2022-12-31.
# Parsed date: 2022/12/31
#
# Original text: We met on 1st of January 2000.
# Parsed date: Date not found
#
# Original text: The concert is scheduled for 15th September, 2021.
# Parsed date: 15/09/2021
#
# Original text: Let's catch up on 02.04.2022.
# Parsed date: 02/04/2022
#
# Original text: The project started on 5/6/19.
# Parsed date: Date not found
#
# Original text: He was born on 1987/11/23.
# Parsed date: 1987/11/23
#
# Original text: Christmas is on 25th Dec 2024.
# Parsed date: 25/12/2024
#
# Original text: The meeting is set for April 03, 2020.
# Parsed date: 03/04/2020
#
# Original text: Her birthdate, noted as 1997-05-20, is in the records.
# Parsed date: 1997/05/20
#
# Original text: Her appointment is on the 2nd of March, 2021.
# Parsed date: Date not found
#
# Original text: The exam date is 2021.11.10.
# Parsed date: 2021/11/10
#
# Original text: They got married on 12/12/12.
# Parsed date: Date not found
#
# Original text: The workshop is on February 15th, 2022.
# Parsed date: 15/02/2022
#
# Original text: Submit your report by 08/31/2021.
# Parsed date: 08/31/2021
#
# Original text: The course starts on 1st July 2023.
# Parsed date: 01/07/2023
#
# Original text: Independence Day is on 4th of July, 2022.
# Parsed date: Date not found
#
# Original text: His birthday is 1995/10/30.
# Parsed date: 1995/10/30
#
# Original text: The new year begins on 01-01-2023.
# Parsed date: 01/01/2023
#
# Original text: The seminar is on 03/14/2022.
# Parsed date: 03/14/2022
#
# Original text: My last day is 31.08.2020.
# Parsed date: 31/08/2020
#
# Original text: The due date is 2020-02-28.
# Parsed date: 2020/02/28
#
# Original text: The holiday starts on Dec 20th, 2021.
# Parsed date: 20/12/2021
#
# Original text: The conference will be held on 5th May 2023.
# Parsed date: 05/05/2023
#
# Original text: They moved in on 12/25/2019.
# Parsed date: 12/25/2019
#
# Original text: The festival begins on March 17, 2022.
# Parsed date: 17/03/2022
#
# Original text: The ceremony is on 11.11.2021.
# Parsed date: 11/11/2021
#
# Original text: The event is on 2023/07/04.
# Parsed date: 2023/07/04
#
# Original text: Her graduation is on May 30th, 2022.
# Parsed date: 30/05/2022
#
# Original text: The release date is 2021-09-09.
# Parsed date: 2021/09/09
#
# Original text: The interview is on 1/2/2022.
# Parsed date: 01/02/2022
#
# Original text: The celebration is on 2022-10-10.
# Parsed date: 2022/10/10
#
# Original text: His wedding is on 6th of August, 2020.
# Parsed date: Date not found
#
# Original text: She was born on 3rd March 1998.
# Parsed date: 03/03/1998
#
# Original text: The opening is on 10/10/2018.
# Parsed date: 10/10/2018
#
# Original text: The deadline is 2020.12.15.
# Parsed date: 2020/12/15
#
# Original text: The party is on 31-12-2022.
# Parsed date: 31/12/2022
#
# Original text: The workshop is on February 29, 2024.
# Parsed date: 29/02/2024
#
# Original text: Vacation starts on 07/15/2021.
# Parsed date: 07/15/2021
#
# Original text: The application is due by 2022-03-03.
# Parsed date: 2022/03/03
#
# Original text: The tournament is on June 1st, 2021.
# Parsed date: 01/06/2021
#
# Original text: The closing date is 08/08/2020.
# Parsed date: 08/08/2020
#
# Original text: The concert is on 2020/09/09.
# Parsed date: 2020/09/09
#
# Original text: The exam is on 01.01.2022.
# Parsed date: 01/01/2022
#
# Original text: Independence Day is 2023-07-04.
# Parsed date: 2023/07/04
#
# Original text: The last date is 30th November 2022.
# Parsed date: 30/11/2022
#
# Original text: The conference is on 15th October 2023.
# Parsed date: 15/10/2023
#
# Original text: His birthdate is 1990-05-20.
# Parsed date: 1990/05/20
#
# Original text: The festival is on 12th August 2024.
# Parsed date: 12/08/2024
#
# Original text: Input
# Parsed date: Date not found
#
# Original text: We are planning to meet on March 5, 2023, for lunch.
# Parsed date: 05/03/2023
#
# Original text: Her birthday, which she celebrates on 07/08/1990, is coming up soon.
# Parsed date: 07/08/1990
#
# Original text: The deadline, unfortunately, is set to 2022-12-31.
# Parsed date: 2022/12/31
#
# Original text: We first met on the 1st of January 2000 at the conference.
# Parsed date: Date not found
#
# Original text: The concert, happening on 15th September 2021, will be amazing.
# Parsed date: 15/09/2021
#
# Original text: Remember, the meeting is on 02.04.2022 at 10 AM.
# Parsed date: 02/04/2022
#
# Original text: Let's wrap up the project by 5/6/19, so we can relax.
# Parsed date: Date not found
#
# Original text: His birth date, recorded as 1987/11/23, was a memorable day.
# Parsed date: 1987/11/23
#
# Original text: We celebrate Christmas every year on 25th Dec, including 2024.
# Parsed date: Date not found
#
# Original text: The meeting is rescheduled to April 03, 2020, as per the latest update.
# Parsed date: 03/04/2020
#
# Original text: Their anniversary is marked on the 2nd of March, 2021.
# Parsed date: Date not found
#
# Original text: The official exam date is now 2021.11.10, per the new schedule.
# Parsed date: 2021/11/10
#
# Original text: They celebrated their wedding on 12/12/12 in grand style.
# Parsed date: Date not found
#
# Original text: Our next workshop is scheduled for February 15th, 2022.
# Parsed date: 15/02/2022
#
# Original text: The submission deadline, noted as 08/31/2021, is fast approaching.
# Parsed date: 08/31/2021
#
# Original text: The course officially begins on 1st July 2023.
# Parsed date: 01/07/2023
#
# Original text: We celebrate Independence Day on the 4th of July every year, including 2022.
# Parsed date: Date not found
#
# Original text: He mentioned that his birth date is 1995/10/30 in the form.
# Parsed date: 1995/10/30
#
# Original text: The new year's celebration begins on 01-01-2023 at midnight.
# Parsed date: 01/01/2023
#
# Original text: We scheduled the seminar for 03/14/2022, don't forget.
# Parsed date: 03/14/2022
#
# Original text: My final working day here is noted as 31.08.2020.
# Parsed date: 31/08/2020
#
# Original text: The project's due date is officially 2020-02-28.
# Parsed date: 2020/02/28
#
# Original text: The holiday vacation starts on Dec 20th, 2021, for everyone.
# Parsed date: 20/12/2021
#
# Original text: The conference, marked for 5th May 2023, is a significant event.
# Parsed date: 05/05/2023
#
# Original text: They officially moved in on 12/25/2019.
# Parsed date: 12/25/2019
#
# Original text: Our festival starts on March 17, 2022, with a parade.
# Parsed date: 17/03/2022
#
# Original text: The ceremony date is fixed as 11.11.2021.
# Parsed date: 11/11/2021
#
# Original text: The big event is planned for 2023/07/04, so mark your calendars.
# Parsed date: 2023/07/04
#
# Original text: Her graduation day is set for May 30th, 2022.
# Parsed date: 30/05/2022
#
# Original text: The software release date is set for 2021-09-09.
# Parsed date: 2021/09/09
#
# Original text: The job interview is on 1/2/2022, don't be late.
# Parsed date: 01/02/2022
#
# Original text: The grand celebration is on 2022-10-10, a date to remember.
# Parsed date: 2022/10/10
#
# Original text: The wedding is on 6th of August, 2020, in the evening.
# Parsed date: Date not found
#
# Original text: She mentioned she was born on the 3rd of March 1998.
# Parsed date: Date not found
#
# Original text: The official opening date is 10/10/2018, as per the announcement.
# Parsed date: 10/10/2018
#
# Original text: The critical deadline is 2020.12.15, please note it.
# Parsed date: 2020/12/15
#
# Original text: The New Year's Eve party is on 31-12-2022, join us!
# Parsed date: 31/12/2022
#
# Original text: The next workshop is on February 29, 2024, due to the leap year.
# Parsed date: 29/02/2024
#
# Original text: Vacation officially starts on 07/15/2021, get ready.
# Parsed date: 07/15/2021
#
# Original text: The application submission date is 2022-03-03.
# Parsed date: 2022/03/03
#
# Original text: The tournament begins on June 1st, 2021, early in the morning.
# Parsed date: 01/06/2021
#
# Original text: The registration closing date is 08/08/2020.
# Parsed date: 08/08/2020
#
# Original text: The music concert is scheduled for 2020/09/09.
# Parsed date: 2020/09/09
#
# Original text: The exam will be held on 01.01.2022, start preparing.
# Parsed date: 01/01/2022
#
# Original text: We celebrate Independence Day on 2023-07-04, as always.
# Parsed date: 2023/07/04
#
# Original text: The final date for submission is 30th November 2022.
# Parsed date: 30/11/2022
#
# Original text: The annual conference is on 15th October 2023, mark your calendars.
# Parsed date: 15/10/2023
#
# Original text: His birthdate, noted as 1990-05-20, is in the records.
# Parsed date: 1990/05/20
#
# Original text: The festival will be celebrated on 12th August 2024, with grand events.
# Parsed date: 12/08/2024
